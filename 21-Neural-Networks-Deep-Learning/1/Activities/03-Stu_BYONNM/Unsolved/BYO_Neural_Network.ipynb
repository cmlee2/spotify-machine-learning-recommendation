# %%
# Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=5000, centers=2, n_features=2, random_state=42, cluster_std=3)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
plt.show()

# %%
# Use sklearn to split dataset

# %%
# Create scaler instance


# Fit the scaler


# Scale the data

# %%
# Create the Keras Sequential model

# %%
# Add our first Dense layer, including the input layer

# %%
# Add the output layer that uses a probability activation function

# %%
# Check the structure of the Sequential model
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 15
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics

# %%
# Fit the model to the training data
# Out:
# Epoch 1/50
# 118/118 [==============================] - 5s 11ms/step - loss: 0.4897 - accuracy: 0.8611
# Epoch 2/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3580 - accuracy: 0.9056
# Epoch 3/50
# 118/118 [==============================] - 1s 8ms/step - loss: 0.2625 - accuracy: 0.9248
# Epoch 4/50
# 118/118 [==============================] - 1s 12ms/step - loss: 0.2086 - accuracy: 0.9320
# Epoch 5/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1780 - accuracy: 0.9381
# Epoch 6/50
# 118/118 [==============================] - 1s 4ms/step - loss: 0.1597 - accuracy: 0.9400
# Epoch 7/50
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1479 - accuracy: 0.9427
# Epoch 8/50
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1399 - accuracy: 0.9451
# Epoch 9/50
# 118/118 [==============================] - 1s 4ms/step - loss: 0.1343 - accuracy: 0.9464
# Epoch 10/50
# 118/118 [==============================] - 1s 6ms/step - loss: 0.1305 - accuracy: 0.9464
# Epoch 11/50
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1280 - accuracy: 0.9480
# Epoch 12/50
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1263 - accuracy: 0.9491
# Epoch 13/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1250 - accuracy: 0.9496
# Epoch 14/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1244 - accuracy: 0.9493
# Epoch 15/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.9499
# Epoch 16/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.9509
# Epoch 17/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1234 - accuracy: 0.9501
# Epoch 18/50
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1232 - accuracy: 0.9509
# Epoch 19/50
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1232 - accuracy: 0.9512
# Epoch 20/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.9512
# Epoch 21/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.9515
# Epoch 22/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.9509
# Epoch 23/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.9509
# Epoch 24/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.9507
# Epoch 25/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1230 - accuracy: 0.9509
# Epoch 26/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.9509
# Epoch 27/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.9512
# Epoch 28/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1230 - accuracy: 0.9504
# Epoch 29/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9515
# Epoch 30/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9509
# Epoch 31/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1230 - accuracy: 0.9509
# Epoch 32/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9512
# Epoch 33/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1230 - accuracy: 0.9507
# Epoch 34/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9507
# Epoch 35/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9509
# Epoch 36/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9507
# Epoch 37/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9504
# Epoch 38/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9501
# Epoch 39/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9509
# Epoch 40/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9515
# Epoch 41/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.9515
# Epoch 42/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.9509
# Epoch 43/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1228 - accuracy: 0.9512
# Epoch 44/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.9509
# Epoch 45/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.9504
# Epoch 46/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9509
# Epoch 47/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 0.9512
# Epoch 48/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9512
# Epoch 49/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1227 - accuracy: 0.9507
# Epoch 50/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1227 - accuracy: 0.9504

# %%
# Evaluate the model using the test data
# Out:
# 40/40 - 0s - loss: 0.1234 - accuracy: 0.9528 - 343ms/epoch - 9ms/step
# Loss: 0.123351089656353, Accuracy: 0.9527999758720398

# %%
# Create a DataFrame containing training history


# Plot the accuracy
