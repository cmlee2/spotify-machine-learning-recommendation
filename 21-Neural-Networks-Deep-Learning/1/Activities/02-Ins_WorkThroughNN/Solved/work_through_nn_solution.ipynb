# %%
# Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
plt.show()

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 15
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 5ms/step - loss: 0.4335 - accuracy: 0.9293
# Epoch 2/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3906 - accuracy: 0.9520
# Epoch 3/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3540 - accuracy: 0.9587
# Epoch 4/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3224 - accuracy: 0.9720
# Epoch 5/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2951 - accuracy: 0.9773
# Epoch 6/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2709 - accuracy: 0.9827
# Epoch 7/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2496 - accuracy: 0.9853
# Epoch 8/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2305 - accuracy: 0.9893
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2133 - accuracy: 0.9920
# Epoch 10/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1979 - accuracy: 0.9920
# Epoch 11/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1838 - accuracy: 0.9920
# Epoch 12/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1710 - accuracy: 0.9920
# Epoch 13/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1594 - accuracy: 0.9933
# Epoch 14/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1488 - accuracy: 0.9933
# Epoch 15/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1392 - accuracy: 0.9947
# Epoch 16/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1304 - accuracy: 0.9947
# Epoch 17/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1224 - accuracy: 0.9947
# Epoch 18/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1151 - accuracy: 0.9947
# Epoch 19/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.9960
# Epoch 20/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1024 - accuracy: 0.9960
# Epoch 21/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0967 - accuracy: 0.9960
# Epoch 22/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0915 - accuracy: 0.9960
# Epoch 23/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0866 - accuracy: 0.9960
# Epoch 24/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0820 - accuracy: 0.9960
# Epoch 25/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0778 - accuracy: 0.9960
# Epoch 26/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0739 - accuracy: 0.9960
# Epoch 27/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0702 - accuracy: 0.9960
# Epoch 28/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0667 - accuracy: 0.9960
# Epoch 29/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0635 - accuracy: 0.9960
# Epoch 30/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0605 - accuracy: 0.9960
# Epoch 31/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0577 - accuracy: 0.9960
# Epoch 32/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0550 - accuracy: 0.9960
# Epoch 33/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0524 - accuracy: 0.9960
# Epoch 34/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0501 - accuracy: 0.9960
# Epoch 35/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9960
# Epoch 36/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0457 - accuracy: 0.9960
# Epoch 37/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0437 - accuracy: 0.9960
# Epoch 38/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0418 - accuracy: 0.9960
# Epoch 39/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0400 - accuracy: 0.9960
# Epoch 40/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0384 - accuracy: 0.9960
# Epoch 41/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 0.9960
# Epoch 42/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0352 - accuracy: 0.9960
# Epoch 43/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0338 - accuracy: 0.9960
# Epoch 44/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9960
# Epoch 45/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0312 - accuracy: 0.9973
# Epoch 46/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0299 - accuracy: 0.9973
# Epoch 47/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
plt.show()

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
plt.show()

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0039 - accuracy: 1.0000 - 329ms/epoch - 41ms/step
# Loss: 0.0039409855380654335, Accuracy: 1.0
